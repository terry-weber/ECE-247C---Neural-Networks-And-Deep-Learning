# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout
from keras.layers import Conv2D,LSTM,BatchNormalization,MaxPooling2D,Reshape
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
## Loading and visualizing the data

## Loading the dataset


X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
print(X_train_valid.shape)
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Adjusting the labels so that 

# Cue onset left - 0
# Cue onset right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769

## Visualizing the data

ch_data = X_train_valid[:,8,:]


class_0_ind = np.where(y_train_valid == 0)
ch_data_class_0 = ch_data[class_0_ind]
avg_ch_data_class_0 = np.mean(ch_data_class_0,axis=0)


class_1_ind = np.where(y_train_valid == 1)
ch_data_class_1 = ch_data[class_1_ind]
avg_ch_data_class_1 = np.mean(ch_data_class_1,axis=0)

class_2_ind = np.where(y_train_valid == 2)
ch_data_class_2 = ch_data[class_2_ind]
avg_ch_data_class_2 = np.mean(ch_data_class_2,axis=0)

class_3_ind = np.where(y_train_valid == 3)
ch_data_class_3 = ch_data[class_3_ind]
avg_ch_data_class_3 = np.mean(ch_data_class_3,axis=0)


plt.plot(np.arange(1000),avg_ch_data_class_0)
plt.plot(np.arange(1000),avg_ch_data_class_1)
plt.plot(np.arange(1000),avg_ch_data_class_2)
plt.plot(np.arange(1000),avg_ch_data_class_3)
plt.axvline(x=500, label='line at t=500',c='cyan')

plt.legend(["Cue Onset left", "Cue Onset right", "Cue onset foot", "Cue onset tongue"])
# Out:
# (2115, 22, 1000)

# %%
def train_data_prep(X,y,sub_sample,average,noise):
    
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,800)
    X = X[:,:,0:500]
    print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,800) -> (sample,22,800/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    
    total_X = X_max
    total_y = y
    print('Shape of X after maxpooling:',total_X.shape)
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    print('Shape of X after averaging+noise and concatenating:',total_X.shape)
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
        
    
    print('Shape of X after subsampling and concatenating:',total_X.shape)
    print('Shape of Y:',total_y.shape)
    return total_X,total_y


def test_data_prep(X):
    
    total_X = None
    
    
    # Trimming the data (sample,22,1000) -> (sample,22,800)
    X = X[:,:,0:500]
    print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,800) -> (sample,22,800/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, 2), axis=3)
    
    
    total_X = X_max
    print('Shape of X after maxpooling:',total_X.shape)
    
    return total_X


def split_train_valid(X, y, num_samples, num_valid):
    ind_valid = np.random.choice(num_samples, num_valid, replace=False)
    ind_train = np.array(list(set(range(num_samples)).difference(set(ind_valid))))
    return X[ind_train], y[ind_train], X[ind_valid], y[ind_valid]

def split_by_person(X, y, person_file, index):
    print(person_file.flatten().shape)
    person_indices = np.asarray(person_file.flatten() == index).nonzero()
    print(X[person_indices[0]].shape)
    return X[person_indices[0]], y[person_indices[0]]

# %%
split_by_person(X_train_valid,  y_train_valid, person_train_valid, 3)
## Preprocessing the dataset

x_train, y_train, x_valid, y_valid = split_train_valid(X_train_valid, y_train_valid, 2115, 443)
x_train,y_train = train_data_prep(x_train,y_train,2,2,True)

x_valid =  test_data_prep(x_valid)
X_test_prep = test_data_prep(X_test) 

## Random splitting and reshaping the data

# First generating the training and validation indices using random splitting
#ind_valid = np.random.choice(8460, 1000, replace=False)
#ind_train = np.array(list(set(range(8460)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
#(x_train, x_valid) = X_train_valid_prep[ind_train], X_train_valid_prep[ind_valid] 
#(y_train, y_valid) = y_train_valid_prep[ind_train], y_train_valid_prep[ind_valid]
print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test, 4)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# (2115,)
# (234, 22, 1000)
# Shape of X after trimming: (1672, 22, 500)
# Shape of X after maxpooling: (1672, 22, 250)
# Shape of X after averaging+noise and concatenating: (3344, 22, 250)
# Shape of X after subsampling and concatenating: (6688, 22, 250)
# Shape of Y: (6688,)
# Shape of X after trimming: (443, 22, 500)
# Shape of X after maxpooling: (443, 22, 250)
# Shape of X after trimming: (443, 22, 500)
# Shape of X after maxpooling: (443, 22, 250)
# Shape of training set: (6688, 22, 250)
# Shape of validation set: (443, 22, 250)
# Shape of training labels: (6688,)
# Shape of validation labels: (443,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 28
#      26 y_train = to_categorical(y_train, 4)
#      27 y_valid = to_categorical(y_valid, 4)
# ---> 28 y_test = to_categorical(y_test, 4)
#      29 print('Shape of training labels after categorical conversion:',y_train.shape)
#      30 print('Shape of validation labels after categorical conversion:',y_valid.shape)
#
# File F:\Programs\anaconda\envs\tensorflow\lib\site-packages\keras\utils\np_utils.py:64, in to_categorical(y, num_classes, dtype)
#      23 @keras_export("keras.utils.to_categorical")
#      24 def to_categorical(y, num_classes=None, dtype="float32"):
#      25     """Converts a class vector (integers) to binary class matrix.
#      26
#      27     E.g. for use with `categorical_crossentropy`.
#    (...)
#      62     [0. 0. 0. 0.]
#      63     """
# ---> 64     y = np.array(y, dtype="int")
#      65     input_shape = y.shape
#      66     if input_shape and input_shape[-1] == 1 and len(input_shape) > 1:
#
# KeyboardInterrupt:

# %%
# Building the CNN model using sequential class
hybrid_cnn_lstm_model = Sequential()

# Conv. block 1
hybrid_cnn_lstm_model.add(Conv2D(filters=25, kernel_size=(5,5), padding='same', activation='elu', input_shape=(250,1,22)))
hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same')) # Read the keras documentation
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.6))

# Conv. block 2
hybrid_cnn_lstm_model.add(Conv2D(filters=50, kernel_size=(5,5), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.6))

# Conv. block 3
hybrid_cnn_lstm_model.add(Conv2D(filters=100, kernel_size=(5,5), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.6))

# Conv. block 4
hybrid_cnn_lstm_model.add(Conv2D(filters=200, kernel_size=(5,5), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.6))

# FC+LSTM layers
hybrid_cnn_lstm_model.add(Flatten()) # Adding a flattening operation to the output of CNN block
# hybrid_cnn_lstm_model.add(Dense((40))) # FC layer with 100 units
# hybrid_cnn_lstm_model.add(Reshape((40,1))) # Reshape my output of FC layer so that it's compatible
# hybrid_cnn_lstm_model.add(LSTM(10, dropout=0.4, recurrent_dropout=0.1, input_shape=(40,1), return_sequences=False))


# Output layer with Softmax activation 
hybrid_cnn_lstm_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation


# Printing the model summary
hybrid_cnn_lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 250, 1, 25)        13775
#
#  max_pooling2d (MaxPooling2D  (None, 84, 1, 25)        0
#  )
#
#  batch_normalization (BatchN  (None, 84, 1, 25)        100
#  ormalization)
#
#  dropout (Dropout)           (None, 84, 1, 25)         0
#
#  conv2d_1 (Conv2D)           (None, 84, 1, 50)         31300
#
#  max_pooling2d_1 (MaxPooling  (None, 28, 1, 50)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 28, 1, 50)        200
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 28, 1, 50)         0
#
#  conv2d_2 (Conv2D)           (None, 28, 1, 100)        125100
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 1, 100)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 10, 1, 100)       400
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 10, 1, 100)        0
#
#  conv2d_3 (Conv2D)           (None, 10, 1, 200)        500200
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 1, 200)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 4, 1, 200)        800
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 4, 1, 200)         0
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 4)                 3204
#
# =================================================================
# Total params: 675,079
# Trainable params: 674,329
# Non-trainable params: 750
# _________________________________________________________________

# %%
# Model parameters
learning_rate = 1e-3
epochs = 100
hybrid_cnn_lstm_optimizer = keras.optimizers.Adam(lr=learning_rate)
# Out:
# F:\Programs\anaconda\envs\tensorflow\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# Compiling the model
hybrid_cnn_lstm_model.compile(loss='categorical_crossentropy',
                 optimizer=hybrid_cnn_lstm_optimizer,
                 metrics=['accuracy'])

# Training and validating the model
hybrid_cnn_lstm_model_results = hybrid_cnn_lstm_model.fit(x_train,
             y_train,
             batch_size=64,
             epochs=epochs,
             validation_data=(x_valid, y_valid), verbose=True)
# Out:
# Epoch 1/100
# 105/105 [==============================] - 2s 9ms/step - loss: 2.1706 - accuracy: 0.2993 - val_loss: 1.3012 - val_accuracy: 0.3634
# Epoch 2/100
# 105/105 [==============================] - 1s 6ms/step - loss: 1.7213 - accuracy: 0.3260 - val_loss: 1.3217 - val_accuracy: 0.3589
# Epoch 3/100
# 105/105 [==============================] - 1s 6ms/step - loss: 1.4555 - accuracy: 0.3690 - val_loss: 1.2117 - val_accuracy: 0.4808
# Epoch 4/100
# 105/105 [==============================] - 1s 6ms/step - loss: 1
100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.7624 - accuracy: 0.6971 - val_loss: 0.7116 - val_accuracy: 0.7111
# Epoch 37/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.7488 - accuracy: 0.7026 - val_loss: 0.8263 - val_accuracy: 0.6637
# Epoch 38/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.7504 - accuracy: 0.7014 - val_loss: 0.7083 - val_accuracy: 0.7314
# Epoch 39/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.7509 - accuracy: 0.7035 - val_loss: 0.7791 - val_accuracy: 0.7133
# Epoch 40/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.7404 - accuracy: 0.6995 - val_loss: 0.7135 - val_accuracy: 0.7269
# Epoch 41/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.7437 - accuracy: 0.7042 - val_loss: 0.7243 - val_accuracy: 0.7065
# Epoch 42/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.7248 - accuracy: 0.7137 - val_loss: 0.6989 - val_accuracy: 0.7223
# Epoch 43/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.7136 - accuracy: 0.7152 - val_loss: 0.7494 - val_accuracy: 0.7111
# Epoch 44/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.7408 - accuracy: 0.7036 - val_loss: 0.7270 - val_accuracy: 0.7111
# Epoch 45/100
# 105/105 [==============================] - 1s 5ms/step - loss: 0.7139 - accuracy: 0.7162 - val_loss: 0.7368 - val_accuracy: 0.7223
# Epoch 46/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6981 - accuracy: 0.7237 - val_loss: 0.7242 - val_accuracy: 0.7111
# Epoch 47/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6993 - accuracy: 0.7235 - val_loss: 0.7212 - val_accuracy: 0.7156
# Epoch 48/100
# 105/105 [==============================] - 1s 5ms/step - loss: 0.7068 - accuracy: 0.7220 - val_loss: 0.8221 - val_accuracy: 0.6659
# Epoch 49/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6987 - accuracy: 0.7198 - val_loss: 0.7075 - val_accuracy: 0.7359
# Epoch 50/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6850 - accuracy: 0.7315 - val_loss: 0.6978 - val_accuracy: 0.7291
# Epoch 51/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6833 - accuracy: 0.7349 - val_loss: 0.7356 - val_accuracy: 0.7088
# Epoch 52/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6759 - accuracy: 0.7315 - val_loss: 0.7043 - val_accuracy: 0.7178
# Epoch 53/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6745 - accuracy: 0.7343 - val_loss: 0.7354 - val_accuracy: 0.7269
# Epoch 54/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6797 - accuracy: 0.7313 - val_loss: 0.7099 - val_accuracy: 0.7156
# Epoch 55/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6792 - accuracy: 0.7301 - val_loss: 0.7145 - val_accuracy: 0.7246
# Epoch 56/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6694 - accuracy: 0.7374 - val_loss: 0.6951 - val_accuracy: 0.7269
# Epoch 57/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6708 - accuracy: 0.7398 - val_loss: 0.7009 - val_accuracy: 0.7088
# Epoch 58/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6573 - accuracy: 0.7377 - val_loss: 0.7313 - val_accuracy: 0.7111
# Epoch 59/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6662 - accuracy: 0.7353 - val_loss: 0.6882 - val_accuracy: 0.7246
# Epoch 60/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6491 - accuracy: 0.7386 - val_loss: 0.7039 - val_accuracy: 0.7359
# Epoch 61/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6520 - accuracy: 0.7497 - val_loss: 0.7131 - val_accuracy: 0.7269
# Epoch 62/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6502 - accuracy: 0.7412 - val_loss: 0.6852 - val_accuracy: 0.7404
# Epoch 63/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6454 - accuracy: 0.7473 - val_loss: 0.7029 - val_accuracy: 0.7291
# Epoch 64/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6445 - accuracy: 0.7470 - val_loss: 0.7143 - val_accuracy: 0.7291
# Epoch 65/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6395 - accuracy: 0.7494 - val_loss: 0.6779 - val_accuracy: 0.7472
# Epoch 66/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6276 - accuracy: 0.7512 - val_loss: 0.7076 - val_accuracy: 0.7065
# Epoch 67/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6467 - accuracy: 0.7484 - val_loss: 0.6821 - val_accuracy: 0.7427
# Epoch 68/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6286 - accuracy: 0.7537 - val_loss: 0.7056 - val_accuracy: 0.7291
# Epoch 69/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6224 - accuracy: 0.7561 - val_loss: 0.6757 - val_accuracy: 0.7314
# Epoch 70/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6440 - accuracy: 0.7457 - val_loss: 0.6879 - val_accuracy: 0.7314
# Epoch 71/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6120 - accuracy: 0.7566 - val_loss: 0.6709 - val_accuracy: 0.7427
# Epoch 72/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6287 - accuracy: 0.7484 - val_loss: 0.6759 - val_accuracy: 0.7314
# Epoch 73/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6104 - accuracy: 0.7588 - val_loss: 0.7103 - val_accuracy: 0.7269
# Epoch 74/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6209 - accuracy: 0.7572 - val_loss: 0.6873 - val_accuracy: 0.7427
# Epoch 75/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6409 - accuracy: 0.7479 - val_loss: 0.6576 - val_accuracy: 0.7540
# Epoch 76/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6022 - accuracy: 0.7599 - val_loss: 0.6677 - val_accuracy: 0.7540
# Epoch 77/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6094 - accuracy: 0.7587 - val_loss: 0.7045 - val_accuracy: 0.7314
# Epoch 78/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5928 - accuracy: 0.7756 - val_loss: 0.6627 - val_accuracy: 0.7494
# Epoch 79/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6106 - accuracy: 0.7552 - val_loss: 0.6632 - val_accuracy: 0.7472
# Epoch 80/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6167 - accuracy: 0.7546 - val_loss: 0.6776 - val_accuracy: 0.7381
# Epoch 81/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6021 - accuracy: 0.7651 - val_loss: 0.6978 - val_accuracy: 0.7314
# Epoch 82/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6095 - accuracy: 0.7588 - val_loss: 0.6885 - val_accuracy: 0.7427
# Epoch 83/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6086 - accuracy: 0.7533 - val_loss: 0.7130 - val_accuracy: 0.7246
# Epoch 84/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6067 - accuracy: 0.7633 - val_loss: 0.6717 - val_accuracy: 0.7494
# Epoch 85/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5985 - accuracy: 0.7703 - val_loss: 0.6658 - val_accuracy: 0.7427
# Epoch 86/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5872 - accuracy: 0.7660 - val_loss: 0.6870 - val_accuracy: 0.7381
# Epoch 87/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5844 - accuracy: 0.7738 - val_loss: 0.6834 - val_accuracy: 0.7336
# Epoch 88/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5903 - accuracy: 0.7721 - val_loss: 0.6551 - val_accuracy: 0.7540
# Epoch 89/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.6016 - accuracy: 0.7645 - val_loss: 0.6778 - val_accuracy: 0.7494
# Epoch 90/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5875 - accuracy: 0.7682 - val_loss: 0.6704 - val_accuracy: 0.7359
# Epoch 91/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5872 - accuracy: 0.7732 - val_loss: 0.6930 - val_accuracy: 0.7404
# Epoch 92/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5867 - accuracy: 0.7666 - val_loss: 0.6886 - val_accuracy: 0.7314
# Epoch 93/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5858 - accuracy: 0.7696 - val_loss: 0.6658 - val_accuracy: 0.7540
# Epoch 94/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5724 - accuracy: 0.7775 - val_loss: 0.7013 - val_accuracy: 0.7472
# Epoch 95/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5655 - accuracy: 0.7769 - val_loss: 0.7020 - val_accuracy: 0.7291
# Epoch 96/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5951 - accuracy: 0.7645 - val_loss: 0.7044 - val_accuracy: 0.7269
# Epoch 97/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5806 - accuracy: 0.7712 - val_loss: 0.6632 - val_accuracy: 0.7359
# Epoch 98/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5821 - accuracy: 0.7760 - val_loss: 0.6998 - val_accuracy: 0.7269
# Epoch 99/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5713 - accuracy: 0.7799 - val_loss: 0.7806 - val_accuracy: 0.6930
# Epoch 100/100
# 105/105 [==============================] - 1s 6ms/step - loss: 0.5880 - accuracy: 0.7718 - val_loss: 0.6724 - val_accuracy: 0.7562

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['accuracy'])
plt.plot(hybrid_cnn_lstm_model_results.history['val_accuracy'])
plt.title('Hybrid CNN-LSTM model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['loss'],'o')
plt.plot(hybrid_cnn_lstm_model_results.history['val_loss'],'o')
plt.title('Hybrid CNN-LSTM model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## Testing the hybrid CNN-LSTM model

hybrid_cnn_lstm_score = hybrid_cnn_lstm_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the hybrid CNN-LSTM model:',hybrid_cnn_lstm_score[1])
# Out:
# Test accuracy of the hybrid CNN-LSTM model: 0.722347617149353
